# %% [markdown]
# Bartosz Bartoszewski
# Nr indeksu: 406690
# Gr: 4
# Kraków, 07.10.2022r.
#
# link do repo: https://github.com/BartoszBartt/aibd_bartoszewskibartosz.git

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Zadanie 3
#Zdefiniuj poniższą funkcję i sporządź jej wykres dla argumentów z danego przedziału:
#f(x) = x**2 +5

def function(x):
    return x**2+5


def plot_functions(start=-1, end=-1, iterations=100, title='Funkcja x**2+5', xlabel='Oś x', ylabel='Oś y'):
    linspace_x = np.linspace(start, end, iterations)
    y = function(linspace_x)

    plt_title = title + " in range <" + str(start) +":" + str(end) +">"
    plt.plot(linspace_x, y)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(plt_title)
    plt.grid()
    plt.show()

ranges = [[-1, 1], [-6, 6], [0, 5]]

for actual_range in ranges:
    start = actual_range[0]
    end = actual_range[1]
    plot_functions(start, end, 100)

# %%
import pandas as pd

data_table = {'Name': ['Bartosz', 'Kasia', 'Lukasz', 'Wiktor', 'Filip'], 
            'Surname': ['Kowalski', 'Strus', 'Myszka', 'Tablet', 'Klocek'], 
            'Age': np.random.randint(100, size=5), 
            'Sex': ['Male','Male','Male','Male','Female']}

data_watch = pd.DataFrame(data=data_table)
print(data_watch)

data_watch.info(verbose=True)

data_watch.describe()
# Out:
#       Name   Surname  Age     Sex
# 0  Bartosz  Kowalski   11    Male
# 1    Kasia     Strus   57    Male
# 2   Lukasz    Myszka   16    Male
# 3   Wiktor    Tablet   69    Male
# 4    Filip    Klocek   80  Female
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Surname  5 non-null      object
#  2   Age      5 non-null      int64
#  3   Sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes
#              Age
# count   5.000000
# mean   46.600000
# std    31.341666
# min    11.000000
# 25%    16.000000
# 50%    57.000000
# 75%    69.000000
# max    80.000000

# %%
data_watch.head(3)
# Out:
#       Name   Surname  Age   Sex
# 0  Bartosz  Kowalski   18  Male
# 1    Kasia     Strus   80  Male
# 2   Lukasz    Myszka   66  Male
